# %%
from PIL import Image
from ultralytics import YOLO

# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
HOME = os.getcwd()
HOME = HOME[0:HOME.find('notebooks')]
os.makedirs(HOME + 'models', exist_ok=True)
MODEL_FOLDER = HOME + 'models\\'
DATA_FOLDER = HOME + 'data\\'

# %%
model = YOLO(MODEL_FOLDER + 'yolov8n.pt')

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# %%
import torch
torch.cuda.empty_cache()

# %%
# kiểm tra phần về device của máy mình trước khi chạy model.train(...)
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("GPU: None")
# Out:
# PyTorch: 2.14.0+cpu
# CUDA available: False
# GPU: None

# %%
## các thay đổi mục đích để kiểm tra pipeline, ko phải tạo model tốt
model.train(
    data=DATA_FOLDER + 'data.yaml',
    epochs=1, # sửa từ 300 về 1 vòng train
    imgsz=640,
    batch=4,   # từ 16 về 4
    device='cpu',  # từ 0 thành 'cpu'
    project=MODEL_FOLDER,
    name='drowning_detection_yolov8',
    save_dir=MODEL_FOLDER,
    # cache=False
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.150 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.149  Python-3.13.3 torch-2.14.0+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# ...
